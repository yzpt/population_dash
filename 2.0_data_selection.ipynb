# %%
import pandas as pd

# %%
selected_data = {'points': [{'curveNumber': 0, 'pointNumber': 86, 'pointIndex': 86, 'location': 21882, 'z': 9713, 'customdata': '59090', 'text': 'Bondues'}, {'curveNumber': 0, 'pointNumber': 270, 'pointIndex': 270, 'location': 22066, 'z': 20829, 'customdata': '59279', 'text': 'Halluin'}, {'curveNumber': 0, 'pointNumber': 404, 'pointIndex': 404, 'location': 22200, 'z': 13173, 'customdata': '59421', 'text': 'Mouvaux'}, {'curveNumber': 0, 'pointNumber': 409, 'pointIndex': 409, 'location': 22205, 'z': 10160, 'customdata': '59426', 'text': 'Neuville-en-Ferrain'}, {'curveNumber': 0, 'pointNumber': 490, 'pointIndex': 490, 'location': 22286, 'z': 13784, 'customdata': '59508', 'text': 'Roncq'}, {'curveNumber': 0, 'pointNumber': 578, 'pointIndex': 578, 'location': 22374, 'z': 99011, 'customdata': '59599', 'text': 'Tourcoing'}, {'curveNumber': 0, 'pointNumber': 627, 'pointIndex': 627, 'location': 22423, 'z': 40836, 'customdata': '59650', 'text': 'Wattrelos'}], 'range': {'mapbox': [[3.092961566407922, 50.993701274368846], [3.6148121523453938, 50.688449380779275]]}}

# %%
selected_data.keys()
# Out:
# dict_keys(['points', 'range'])

# %%
selected_data['points']
# Out:
# [{'curveNumber': 0,
#   'pointNumber': 86,
#   'pointIndex': 86,
#   'location': 21882,
#   'z': 9713,
#   'customdata': '59090',
#   'text': 'Bondues'},
#  {'curveNumber': 0,
#   'pointNumber': 270,
#   'pointIndex': 270,
#   'location': 22066,
#   'z': 20829,
#   'customdata': '59279',
#   'text': 'Halluin'},
#  {'curveNumber': 0,
#   'pointNumber': 404,
#   'pointIndex': 404,
#   'location': 22200,
#   'z': 13173,
#   'customdata': '59421',
#   'text': 'Mouvaux'},
#  {'curveNumber': 0,
#   'pointNumber': 409,
#   'pointIndex': 409,
#   'location': 22205,
#   'z': 10160,
#   'customdata': '59426',
#   'text': 'Neuville-en-Ferrain'},
#  {'curveNumber': 0,
#   'pointNumber': 490,
#   'pointIndex': 490,
#   'location': 22286,
#   'z': 13784,
#   'customdata': '59508',
#   'text': 'Roncq'},
#  {'curveNumber': 0,
#   'pointNumber': 578,
#   'pointIndex': 578,
#   'location': 22374,
#   'z': 99011,
#   'customdata': '59599',
#   'text': 'Tourcoing'},
#  {'curveNumber': 0,
#   'pointNumber': 627,
#   'pointIndex': 627,
#   'location': 22423,
#   'z': 40836,
#   'customdata': '59650',
#   'text': 'Wattrelos'}]

# %%
selected_codes = [x['customdata'] for x in selected_data['points']]
selected_codes
# Out:
# ['59090', '59279', '59421', '59426', '59508', '59599', '59650']

# %%
from typing import List
import geopandas as gpd
import plotly.graph_objects as go



def plot_historic_population(
    codgeo: str = None,
    codgeo_list: List[str] = None,
) -> go.Figure:
    global df_historic_population
    global filtered_gdf
    
    # check if codgeo is list or not
    if isinstance(codgeo, str):
        codgeo_list = [codgeo]
    
    # Filter and transpose the DataFrame
    df = df_historic_population[df_historic_population['codgeo'].isin(codgeo_list)].T.reset_index()[3:]
    
    # Extract the name of the region or city
    nom = df.iloc[0, 1]
    
    # Clean and rename columns
    df = df[1:]
    df.columns = ['year', 'population']
    
    # Convert 'year' to datetime
    df['year'] = pd.to_datetime(df['year'], format='%Y')
    
    # Sort values by year
    df.sort_values('year', ascending=True, inplace=True)
    
    # Create figure
    fig = go.Figure()
    
    # Add scatter plot with lines and markers
    fig.add_trace(
        go.Scatter(
            x=df['year'],
            y=df['population'],
            mode='lines+markers',
            line_shape='spline',
        )
    )
    
    # Update layout with titles and styling
    fig.update_layout(
        title=dict(
            text=f'{nom}',
            x=.95,
            y=0.95,
            xanchor='right',
            yanchor='top',
        ),
        yaxis_title='Population',
        xaxis=dict(type='date'),
        template='plotly_dark',
        margin={"r":10,"t":30,"l":10,"b":10},
        height=200
    )

    return fig

# %%
df_historic_population = pd.read_csv('app/pop_historique_extended.csv', dtype={0: str, 2: str})
df_historic_population
# Out:
#       codgeo  region departement                      nom   2021   2020  \
# 0      01001      84          01  L'Abergement-Clémenciat    832    806
# 1      01002      84          01    L'Abergement-de-Varey    267    262
# 2      01004      84          01        Ambérieu-en-Bugey  14854  14288
# 3      01005      84          01      Ambérieux-en-Dombes   1897   1782
# 4      01006      84          01                  Ambléon    113    113
# ...      ...     ...         ...                      ...    ...    ...
# 34942  97420       4         974           Sainte-Suzanne  24293  24086
# 34943  97421       4         974                  Salazie   7243   7310
# 34944  97422       4         974                Le Tampon  81943  80778
# 34945  97423       4         974        Les Trois-Bassins   6899   6953
# 34946  97424       4         974                   Cilaos   5390   5568
#
#         2019   2018   2017   2016  ...  1926  1921  1911  1906  1901  1896  \
# 0        779    771    776    767  ...   543   566   560   629   637   572
# 1        256    253    248    243  ...   253   256   291   323   357   391
# 2      14134  14204  14035  14081  ...  5705  4796  4334  4100  4023  3548
# 3       1751   1720   1689   1671  ...   690   698   805   805   835   852
# 4        112    112    111    110  ...   161   150   159   193   200   206
# ...      ...    ...    ...    ...  ...   ...   ...   ...   ...   ...   ...
# 34942  24065  23718  23505  23224  ...     0     0     0     0     0     0
# 34943   7136   7224   7312   7400  ...     0     0     0     0     0     0
# 34944  79824  79385  78629  77283  ...     0     0     0     0     0     0
# 34945   7015   7076   7139   7111  ...     0     0     0     0     0     0
# 34946   5538   5492   5456   5403  ...     0     0     0     0     0     0
#
#        1891  1886  1881  1876
# 0       594   622   605   604
# 1       421   486   490   484
# 2      3635  3618  3396  3427
# 3       862   882   879   848
# 4       200   200   213   191
# ...     ...   ...   ...   ...
# 34942     0     0     0     0
# 34943     0     0     0     0
# 34944     0     0     0     0
# 34945     0     0     0     0
# 34946     0     0     0     0
#
# [34947 rows x 39 columns]

# %%
codgeo_list = ['01005', '01006','01001']
df = df_historic_population[df_historic_population['codgeo'].isin(codgeo_list)].T[4:]
df['sum'] = df.sum(axis=1)
df.reset_index(inplace=True)
df.rename(columns={'index':'year'}, inplace=True)
df = df[['year','sum']].sort_values('year', ascending=True).reset_index(drop=True)
df
# Out:
#     year   sum
# 0   1876  1643
# 1   1881  1697
# 2   1886  1704
# 3   1891  1656
# 4   1896  1630
# 5   1901  1672
# 6   1906  1627
# 7   1911  1524
# 8   1921  1414
# 9   1926  1394
# 10  1931  1293
# 11  1936  1240
# 12  1954  1105
# 13  1962  1102
# 14  1968  1082
# 15  1975  1206
# 16  1982  1390
# 17  1990  1811
# 18  1999  2222
# 19  2006  2367
# 20  2007  2473
# 21  2008  2481
# 22  2009  2499
# 23  2010  2516
# 24  2011  2492
# 25  2012  2529
# 26  2013  2510
# 27  2014  2503
# 28  2015  2495
# 29  2016  2548
# 30  2017  2576
# 31  2018  2603
# 32  2019  2642
# 33  2020  2701
# 34  2021  2842

# %%
f.columns = f.iloc[0].reset_index(drop=True)
f = f[4:]
f['sum'] = f.sum(axis=1)
f
# rename index to year
f.index.name = 'year'
f.reset_index(inplace=True)
f = f[['year', 'sum']]
f
# drop idnex
f = f.reset_index(drop=True)
f
